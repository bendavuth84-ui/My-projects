# %% [markdown]
# <a href="https://colab.research.google.com/github/bendavuth84-ui/My-projects/blob/main/Trre_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    """Represents a node in a binary expression tree."""
    def __init__(self, element, left=None, right=None):
        self.element = element
        self.left = left
        self.right = right

    def is_operator(self):
        """Helper method to check if the node's element is an operator."""
        return self.element in ('+', '-', '*', '/')

# %%
class Node:
 def __init__(self,key):
    self.key=key
    self.left=Node
    self.right=Node

class BinarySearchTree:
  def __init__(self):
    self.root=Node
  def __init__(self,key):

     self .root= self.insert_recursively(self.root.key);
